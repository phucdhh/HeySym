# %%
# %load_ai
# Out:
# ## 🤖 AI Models
#
# ### 🦙 Ollama
# | Cách dùng | Loại |
# |-----------|------|
# | `%%ai ollama:qwen3-vl:235b-cloud` | ☁️ cloud |
# | `%%ai ollama:deepseek-r1:8b` | 💻 local |
# | `%%ai ollama:glm-4.7:cloud` | ☁️ cloud |
# | `%%ai ollama:kimi-k2-thinking:cloud` | ☁️ cloud |
# | `%%ai ollama:deepseek-v3.1:671b-cloud` | ☁️ cloud |
# | `%%ai ollama:glm-4.6:cloud` | ☁️ cloud |
# | `%%ai ollama:gemini-3-pro-preview:latest` | 💻 local |
# | `%%ai ollama:gpt-oss:120b-cloud` | ☁️ cloud |
# | `%%ai ollama:deepseek-v3.2:cloud` | ☁️ cloud |
#
# ### ⚡ Cerebras
# | Cách dùng | Loại |
# |-----------|------|
# | `%%ai cerebras:llama3.1-8b` | ⚡ cloud |
# | `%%ai cerebras:qwen-3-235b-a22b-instruct-2507` | ⚡ cloud |
# | `%%ai cerebras:gpt-oss-120b` | ⚡ cloud |
# | `%%ai cerebras:zai-glm-4.7` | ⚡ cloud |
#
# > Gõ `%models` để xem lại danh sách này bất cứ lúc nào.

# %%
# %%ai cerebras:llama3.1-8b
# Giải thích machine learning cho học sinh lớp 10
# Out:
# Cannot determine model provider from model ID 'cerebras:llama3.1-8b'.
#
# To see a list of models you can use, run '%ai list'
#
# If you were trying to run a command, run '%ai help' to see a list of commands.
